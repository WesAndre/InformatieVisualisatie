# %%
import pandas as pd

# %%
df1 = pd.read_csv('owid-covid-data.csv')
df1['date'] = pd.to_datetime(df1['date'])
df1 = df1[df1['date'].dt.strftime('%Y') == '2021']
df1 = df1.groupby('location', as_index=False).max(numeric_only=True)

df1 = df1.drop(['new_cases', 'new_cases_smoothed', 'new_deaths', 'new_deaths_smoothed', 'new_cases_per_million', 'new_cases_smoothed_per_million', 'new_deaths_per_million', 'new_deaths_smoothed_per_million', 'new_tests', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations', 'new_vaccinations_smoothed',  'new_vaccinations_smoothed_per_million', 'new_people_vaccinated_smoothed', 'new_people_vaccinated_smoothed_per_hundred'   ], axis= 1)

# Read the second dataset
df2 = pd.read_csv('Life expectancy.csv')
df2 = df2.rename(columns={'Country': 'location'})
df2 = df2.groupby('location', as_index=False).max(numeric_only=True)

concat = merged_df = df1.merge(df2, on='location', how='inner')

# %%
concat.corr(method='pearson', numeric_only=True)
# Out:
#                                          total_cases  total_deaths  \
# total_cases                                 1.000000      0.937141
# total_deaths                                0.937141      1.000000
# total_cases_per_million                     0.167460      0.132857
# total_deaths_per_million                    0.203573      0.311626
# reproduction_rate                           0.036414      0.005669
# icu_patients                                0.971446      0.979844
# icu_patients_per_million                    0.162299      0.197846
# hosp_patients                               0.964310      0.973948
# hosp_patients_per_million                   0.023647      0.064921
# weekly_icu_admissions                       0.939758      0.916710
# weekly_icu_admissions_per_million          -0.126333     -0.091342
# weekly_hosp_admissions                      0.992794      0.990628
# weekly_hosp_admissions_per_million          0.137138      0.132478
# total_tests                                 0.916066      0.770131
# total_tests_per_thousand                   -0.002002     -0.050721
# positive_rate                              -0.064752     -0.042398
# tests_per_case                             -0.034516     -0.036568
# total_vaccinations                          0.370503      0.338152
# people_vaccinated                           0.417655      0.379069
# people_fully_vaccinated                     0.359571      0.330899
# total_boosters                              0.561274      0.514788
# total_vaccinations_per_hundred              0.174356      0.171947
# people_vaccinated_per_hundred               0.196168      0.209323
# people_fully_vaccinated_per_hundred         0.158059      0.167015
# total_boosters_per_hundred                  0.111840      0.049749
# stringency_index                            0.115025      0.111346
# population_density                         -0.018996     -0.039330
# median_age                                  0.160383      0.144811
# aged_65_older                               0.160039      0.129251
# aged_70_older                               0.151739      0.120299
# gdp_per_capita                              0.136246      0.087863
# extreme_poverty                            -0.102615     -0.132059
# cardiovasc_death_rate                      -0.143052     -0.158764
# diabetes_prevalence                         0.035303      0.063810
# female_smokers                              0.095415      0.063591
# male_smokers                               -0.113388     -0.124684
# handwashing_facilities                      0.096789      0.174103
# hospital_beds_per_thousand                  0.000921     -0.023770
# life_expectancy                             0.145215      0.146152
# human_development_index                     0.174371      0.165796
# population                                  0.482534      0.429905
# excess_mortality_cumulative_absolute        0.836821      0.941908
# excess_mortality_cumulative                 0.019447      0.180325
# excess_mortality                           -0.111634      0.034547
# excess_mortality_cumulative_per_million     0.058326      0.161195
# Life Expectancy (years) - Men               0.117024      0.114845
# Life Expectancy (years) - Women             0.104130      0.114086
# Happiness Score                             0.136224      0.142999
# Fertility Rate (births per woman)          -0.164034     -0.176556
#
#                                          total_cases_per_million  \
# total_cases                                             0.167460
# total_deaths                                            0.132857
# total_cases_per_million                                 1.000000
# total_deaths_per_million                                0.631722
# reproduction_rate                                       0.043009
# icu_patients                                            0.123010
# icu_patients_per_million                                0.363238
# hosp_patients                                           0.092709
# hosp_patients_per_million                               0.321412
# weekly_icu_admissions                                  -0.347225
# weekly_icu_admissions_per_million                       0.088466
# weekly_hosp_admissions                                  0.130931
# weekly_hosp_admissions_per_million                      0.376708
# total_tests                                             0.146313
# total_tests_per_thousand                                0.471104
# positive_rate                                          -0.096590
# tests_per_case                                         -0.132824
# total_vaccinations                                     -0.088770
# people_vaccinated                                      -0.098311
# people_fully_vaccinated                                -0.094604
# total_boosters                                         -0.041280
# total_vaccinations_per_hundred                          0.535003
# people_vaccinated_per_hundred                           0.499800
# people_fully_vaccinated_per_hundred                     0.486608
# total_boosters_per_hundred                              0.414591
# stringency_index                                        0.308249
# population_density                                      0.051597
# median_age                                              0.673741
# aged_65_older                                           0.583119
# aged_70_older                                           0.589169
# gdp_per_capita                                          0.449686
# extreme_poverty                                        -0.513082
# cardiovasc_death_rate                                  -0.236874
# diabetes_prevalence                                     0.034374
# female_smokers                                          0.616045
# male_smokers                                            0.282265
# handwashing_facilities                                  0.579875
# hospital_beds_per_thousand                              0.446028
# life_expectancy                                         0.609756
# human_development_index                                 0.666232
# population                                             -0.134924
# excess_mortality_cumulative_absolute                   -0.048197
# excess_mortality_cumulative                            -0.056057
# excess_mortality                                       -0.200307
# excess_mortality_cumulative_per_million                 0.179994
# Life Expectancy (years) - Men                           0.602927
# Life Expectancy (years) - Women                         0.601579
# Happiness Score                                         0.573284
# Fertility Rate (births per woman)                      -0.611932
#
#                                          total_deaths_per_million  \
# total_cases                                              0.203573
# total_deaths                                             0.311626
# total_cases_per_million                                  0.631722
# total_deaths_per_million                                 1.000000
# reproduction_rate                                       -0.051287
# icu_patients                                             0.261311
# icu_patients_per_million                                 0.693873
# hosp_patients                                            0.280770
# hosp_patients_per_million                                0.862238
# weekly_icu_admissions                                    0.343796
# weekly_icu_admissions_per_million                        0.546123
# weekly_hosp_admissions                                   0.339385
# weekly_hosp_admissions_per_million                       0.591059
# total_tests                                              0.106741
# total_tests_per_thousand                                 0.041557
# positive_rate                                           -0.012700
# tests_per_case                                          -0.117243
# total_vaccinations                                      -0.050305
# people_vaccinated                                       -0.055458
# people_fully_vaccinated                                 -0.053302
# total_boosters                                           0.006147
# total_vaccinations_per_hundred                           0.270205
# people_vaccinated_per_hundred                            0.283579
# people_fully_vaccinated_per_hundred                      0.266376
# total_boosters_per_hundred                              -0.034864
# stringency_index                                         0.215496
# population_density                                      -0.093493
# median_age                                               0.530340
# aged_65_older                                            0.501083
# aged_70_older                                            0.505691
# gdp_per_capita                                           0.108139
# extreme_poverty                                         -0.443414
# cardiovasc_death_rate                                   -0.106345
# diabetes_prevalence                                      0.030696
# female_smokers                                           0.515055
# male_smokers                                             0.203970
# handwashing_facilities                                   0.570434
# hospital_beds_per_thousand                               0.350987
# life_expectancy                                          0.431578
# human_development_index                                  0.475370
# population                                              -0.088583
# excess_mortality_cumulative_absolute                     0.241232
# excess_mortality_cumulative                              0.451169
# excess_mortality                                         0.250236
# excess_mortality_cumulative_per_million                  0.734644
# Life Expectancy (years) - Men                            0.411074
# Life Expectancy (years) - Women                          0.451606
# Happiness Score                                          0.362388
# Fertility Rate (births per woman)                       -0.523698
#
#                                          reproduction_rate  icu_patients  \
# total_cases                                       0.036414      0.971446
# total_deaths                                      0.005669      0.979844
# total_cases_per_million                           0.043009      0.123010
# total_deaths_per_million                         -0.051287      0.261311
# reproduction_rate                                 1.000000     -0.048327
# icu_patients                                     -0.048327      1.000000
# icu_patients_per_million                         -0.077289      0.286727
# hosp_patients                                    -0.061384      0.980463
# hosp_patients_per_million                        -0.226948      0.020363
# weekly_icu_admissions                            -0.246827      0.984502
# weekly_icu_admissions_per_million                -0.350228     -0.069161
# weekly_hosp_admissions                           -0.117001      0.976821
# weekly_hosp_admissions_per_million               -0.414775      0.089044
# total_tests                                       0.013236      0.879229
# total_tests_per_thousand                          0.014017     -0.150892
# positive_rate                                     0.013221      0.127326
# tests_per_case                                   -0.036567     -0.124273
# total_vaccinations                                0.020603      0.942578
# people_vaccinated                                 0.028894      0.940491
# people_fully_vaccinated                           0.024737      0.921139
# total_boosters                                   -0.080435      0.910898
# total_vaccinations_per_hundred                    0.201781      0.079771
# people_vaccinated_per_hundred                     0.188658      0.137867
# people_fully_vaccinated_per_hundred               0.207040      0.077544
# total_boosters_per_hundred                       -0.014978      0.010338
# stringency_index                                  0.159147      0.017485
# population_density                                0.165296     -0.126721
# median_age                                        0.115079     -0.026272
# aged_65_older                                     0.070609     -0.007520
# aged_70_older                                     0.048665     -0.010618
# gdp_per_capita                                    0.191033      0.128709
# extreme_poverty                                  -0.021334      0.033475
# cardiovasc_death_rate                            -0.116734     -0.129237
# diabetes_prevalence                               0.010608      0.271904
# female_smokers                                    0.071908      0.043300
# male_smokers                                     -0.005338     -0.156633
# handwashing_facilities                            0.005014     -1.000000
# hospital_beds_per_thousand                       -0.009240     -0.019061
# life_expectancy                                   0.174493     -0.039502
# human_development_index                           0.156869      0.126925
# population                                        0.048207      0.943325
# excess_mortality_cumulative_absolute              0.009302      0.967908
# excess_mortality_cumulative                      -0.126011      0.100055
# excess_mortality                                 -0.033201     -0.079881
# excess_mortality_cumulative_per_million          -0.118787      0.081791
# Life Expectancy (years) - Men                     0.180734     -0.089677
# Life Expectancy (years) - Women                   0.164567     -0.046829
# Happiness Score                                   0.101497     -0.002483
# Fertility Rate (births per woman)                -0.102062     -0.033729
#
#                                          icu_patients_per_million  \
# total_cases                                              0.162299
# total_deaths                                             0.197846
# total_cases_per_million                                  0.363238
# total_deaths_per_million                                 0.693873
# reproduction_rate                                       -0.077289
# icu_patients                                             0.286727
# icu_patients_per_million                                 1.000000
# hosp_patients                                            0.331527
# hosp_patients_per_million                                0.735568
# weekly_icu_admissions                                    0.388985
# weekly_icu_admissions_per_million                        0.680839
# weekly_hosp_admissions                                   0.113615
# weekly_hosp_admissions_per_million                       0.259409
# total_tests                                              0.077103
# total_tests_per_thousand                                -0.061697
# positive_rate                                           -0.065172
# tests_per_case                                          -0.266197
# total_vaccinations                                       0.102983
# people_vaccinated                                        0.093812
# people_fully_vaccinated                                  0.077683
# total_boosters                                           0.171563
# total_vaccinations_per_hundred                           0.205749
# people_vaccinated_per_hundred                            0.232197
# people_fully_vaccinated_per_hundred                      0.140424
# total_boosters_per_hundred                               0.218871
# stringency_index                                         0.208742
# population_density                                      -0.123296
# median_age                                               0.064394
# aged_65_older                                            0.006958
# aged_70_older                                            0.044021
# gdp_per_capita                                          -0.208892
# extreme_poverty                                         -0.087034
# cardiovasc_death_rate                                    0.215316
# diabetes_prevalence                                      0.030873
# female_smokers                                           0.544249
# male_smokers                                             0.436175
# handwashing_facilities                                  -1.000000
# hospital_beds_per_thousand                               0.136112
# life_expectancy                                         -0.231623
# human_development_index                                 -0.115652
# population                                               0.059793
# excess_mortality_cumulative_absolute                     0.182142
# excess_mortality_cumulative                              0.275500
# excess_mortality                                         0.340472
# excess_mortality_cumulative_per_million                  0.424471
# Life Expectancy (years) - Men                           -0.146569
# Life Expectancy (years) - Women                         -0.096261
# Happiness Score                                         -0.136788
# Fertility Rate (births per woman)                       -0.236756
#
#                                          hosp_patients  \
# total_cases                                   0.964310
# total_deaths                                  0.973948
# total_cases_per_million                       0.092709
# total_deaths_per_million                      0.280770
# reproduction_rate                            -0.061384
# icu_patients                                  0.980463
# icu_patients_per_million                      0.331527
# hosp_patients                                 1.000000
# hosp_patients_per_million                     0.129754
# weekly_icu_admissions                         0.932184
# weekly_icu_admissions_per_million             0.381740
# weekly_hosp_admissions                        0.985174
# weekly_hosp_admissions_per_million            0.255559
# total_tests                                   0.920871
# total_tests_per_thousand                     -0.136436
# positive_rate                                 0.011513
# tests_per_case                               -0.120857
# total_vaccinations                            0.954466
# people_vaccinated                             0.945344
# people_fully_vaccinated                       0.934768
# total_boosters                                0.953178
# total_vaccinations_per_hundred               -0.001416
# people_vaccinated_per_hundred                 0.047449
# people_fully_vaccinated_per_hundred           0.047937
# total_boosters_per_hundred                   -0.050521
# stringency_index                              0.036361
# population_density                           -0.049093
# median_age                                    0.030559
# aged_65_older                                 0.044493
# aged_70_older                                 0.024078
# gdp_per_capita                                0.057916
# extreme_poverty                               0.041845
# cardiovasc_death_rate                        -0.064832
# diabetes_prevalence                           0.281881
# female_smokers                               -0.046767
# male_smokers                                 -0.100830
# handwashing_facilities                             NaN
# hospital_beds_per_thousand                   -0.012802
# life_expectancy                              -0.046255
# human_development_index                       0.066117
# population                                    0.957886
# excess_mortality_cumulative_absolute          0.959247
# excess_mortality_cumulative                   0.118742
# excess_mortality                             -0.072691
# excess_mortality_cumulative_per_million       0.136494
# Life Expectancy (years) - Men                -0.098621
# Life Expectancy (years) - Women              -0.038520
# Happiness Score                              -0.117752
# Fertility Rate (births per woman)            -0.106504
#
#                                          hosp_patients_per_million  \
# total_cases                                               0.023647
# total_deaths                                              0.064921
# total_cases_per_million                                   0.321412
# total_deaths_per_million                                  0.862238
# reproduction_rate                                        -0.226948
# icu_patients                                              0.020363
# icu_patients_per_million                                  0.735568
# hosp_patients                                             0.129754
# hosp_patients_per_million                                 1.000000
# weekly_icu_admissions                                     0.186739
# weekly_icu_admissions_per_million                         0.749693
# weekly_hosp_admissions                                    0.180158
# weekly_hosp_admissions_per_million                        0.814683
# total_tests                                               0.011645
# total_tests_per_thousand                                 -0.117065
# positive_rate                                             0.133874
# tests_per_case                                           -0.227828
# total_vaccinations                                       -0.055230
# people_vaccinated                                        -0.062698
# people_fully_vaccinated                                  -0.067771
# total_boosters                                            0.041406
# total_vaccinations_per_hundred                           -0.541327
# people_vaccinated_per_hundred                            -0.596935
# people_fully_vaccinated_per_hundred                      -0.321358
# total_boosters_per_hundred                               -0.153836
# stringency_index                                          0.071394
# population_density                                       -0.159216
# median_age                                                0.293115
# aged_65_older                                             0.208513
# aged_70_older                                             0.220670
# gdp_per_capita                                           -0.453128
# extreme_poverty                                          -0.002453
# cardiovasc_death_rate                                     0.791539
# diabetes_prevalence                                      -0.041254
# female_smokers                                            0.411776
# male_smokers                                              0.558695
# handwashing_facilities                                         NaN
# hospital_beds_per_thousand                                0.315122
# life_expectancy                                          -0.490087
# human_development_index                                  -0.429597
# population                                               -0.042019
# excess_mortality_cumulative_absolute                      0.090848
# excess_mortality_cumulative                               0.413500
# excess_mortality                                          0.578668
# excess_mortality_cumulative_per_million                   0.856739
# Life Expectancy (years) - Men                            -0.460204
# Life Expectancy (years) - Women                          -0.437035
# Happiness Score                                          -0.584201
# Fertility Rate (births per woman)                        -0.279441
#
#                                          weekly_icu_admissions  ...  \
# total_cases                                           0.939758  ...
# total_deaths                                          0.916710  ...
# total_cases_per_million                              -0.347225  ...
# total_deaths_per_million                              0.343796  ...
# reproduction_rate                                    -0.246827  ...
# icu_patients                                          0.984502  ...
# icu_patients_per_million                              0.388985  ...
# hosp_patients                                         0.932184  ...
# hosp_patients_per_million                             0.186739  ...
# weekly_icu_admissions                                 1.000000  ...
# weekly_icu_admissions_per_million                     0.051102  ...
# weekly_hosp_admissions                                0.947507  ...
# weekly_hosp_admissions_per_million                   -0.127411  ...
# total_tests                                           0.903268  ...
# total_tests_per_thousand                             -0.247861  ...
# positive_rate                                        -0.192304  ...
# tests_per_case                                       -0.315241  ...
# total_vaccinations                                    0.927048  ...
# people_vaccinated                                     0.928231  ...
# people_fully_vaccinated                               0.928926  ...
# total_boosters                                        0.901214  ...
# total_vaccinations_per_hundred                        0.378278  ...
# people_vaccinated_per_hundred                         0.434155  ...
# people_fully_vaccinated_per_hundred                   0.285478  ...
# total_boosters_per_hundred                            0.307498  ...
# stringency_index                                      0.164436  ...
# population_density                                   -0.164972  ...
# median_age                                            0.281547  ...
# aged_65_older                                         0.321964  ...
# aged_70_older                                         0.347857  ...
# gdp_per_capita                                       -0.189320  ...
# extreme_poverty                                       0.837696  ...
# cardiovasc_death_rate                                -0.317011  ...
# diabetes_prevalence                                   0.130166  ...
# female_smokers                                        0.480317  ...
# male_smokers                                         -0.030908  ...
# handwashing_facilities                                     NaN  ...
# hospital_beds_per_thousand                            0.338231  ...
# life_expectancy                                       0.210826  ...
# human_development_index                              -0.079186  ...
# population                                            0.918962  ...
# excess_mortality_cumulative_absolute                  0.766124  ...
# excess_mortality_cumulative                           0.094929  ...
# excess_mortality                                     -0.494022  ...
# excess_mortality_cumulative_per_million              -0.026044  ...
# Life Expectancy (years) - Men                         0.179148  ...
# Life Expectancy (years) - Women                       0.314733  ...
# Happiness Score                                      -0.264514  ...
# Fertility Rate (births per woman)                     0.006872  ...
#
#                                          human_development_index  population  \
# total_cases                                             0.174371    0.482534
# total_deaths                                            0.165796    0.429905
# total_cases_per_million                                 0.666232   -0.134924
# total_deaths_per_million                                0.475370   -0.088583
# reproduction_rate                                       0.156869    0.048207
# icu_patients                                            0.126925    0.943325
# icu_patients_per_million                               -0.115652    0.059793
# hosp_patients                                           0.066117    0.957886
# hosp_patients_per_million                              -0.429597   -0.042019
# weekly_icu_admissions                                  -0.079186    0.918962
# weekly_icu_admissions_per_million                      -0.557445   -0.129134
# weekly_hosp_admissions                                  0.064650    0.982502
# weekly_hosp_admissions_per_million                     -0.639942    0.109368
# total_tests                                             0.173963    0.719020
# total_tests_per_thousand                                0.431105   -0.096438
# positive_rate                                          -0.336068   -0.140124
# tests_per_case                                         -0.003561    0.675064
# total_vaccinations                                      0.045370    0.941221
# people_vaccinated                                       0.031818    0.972318
# people_fully_vaccinated                                 0.042353    0.939647
# total_boosters                                          0.103699    0.893960
# total_vaccinations_per_hundred                          0.817405    0.072919
# people_vaccinated_per_hundred                           0.804718    0.101884
# people_fully_vaccinated_per_hundred                     0.792065    0.079893
# total_boosters_per_hundred                              0.622457   -0.079408
# stringency_index                                        0.419624    0.074698
# population_density                                      0.150591    0.005155
# median_age                                              0.893743    0.028035
# aged_65_older                                           0.758129   -0.010830
# aged_70_older                                           0.744240   -0.028213
# gdp_per_capita                                          0.731169   -0.059628
# extreme_poverty                                        -0.762501   -0.027885
# cardiovasc_death_rate                                  -0.448622    0.008732
# diabetes_prevalence                                     0.204636    0.028852
# female_smokers                                          0.533907   -0.147377
# male_smokers                                            0.094643    0.021640
# handwashing_facilities                                  0.843090    0.034505
# hospital_beds_per_thousand                              0.587335   -0.044438
# life_expectancy                                         0.917206   -0.006814
# human_development_index                                 1.000000   -0.029245
# population                                             -0.029245    1.000000
# excess_mortality_cumulative_absolute                   -0.055650    0.918142
# excess_mortality_cumulative                            -0.514867    0.081974
# excess_mortality                                       -0.647824   -0.044750
# excess_mortality_cumulative_per_million                -0.303433    0.058505
# Life Expectancy (years) - Men                           0.903670   -0.024765
# Life Expectancy (years) - Women                         0.900672   -0.046640
# Happiness Score                                         0.902571   -0.062944
# Fertility Rate (births per woman)                      -0.866658   -0.052780
#
#                                          excess_mortality_cumulative_absolute  \
# total_cases                                                          0.836821
# total_deaths                                                         0.941908
# total_cases_per_million                                             -0.048197
# total_deaths_per_million                                             0.241232
# reproduction_rate                                                    0.009302
# icu_patients                                                         0.967908
# icu_patients_per_million                                             0.182142
# hosp_patients                                                        0.959247
# hosp_patients_per_million                                            0.090848
# weekly_icu_admissions                                                0.766124
# weekly_icu_admissions_per_million                                   -0.089635
# weekly_hosp_admissions                                               0.984868
# weekly_hosp_admissions_per_million                                   0.129509
# total_tests                                                          0.648044
# total_tests_per_thousand                                            -0.117449
# positive_rate                                                        0.067041
# tests_per_case                                                      -0.103333
# total_vaccinations                                                   0.871729
# people_vaccinated                                                    0.890732
# people_fully_vaccinated                                              0.870580
# total_boosters                                                       0.810726
# total_vaccinations_per_hundred                                      -0.027872
# people_vaccinated_per_hundred                                        0.031136
# people_fully_vaccinated_per_hundred                                 -0.019110
# total_boosters_per_hundred                                          -0.025425
# stringency_index                                                    -0.006833
# population_density                                                  -0.083127
# median_age                                                          -0.113978
# aged_65_older                                                       -0.081212
# aged_70_older                                                       -0.088613
# gdp_per_capita                                                      -0.058422
# extreme_poverty                                                      0.166553
# cardiovasc_death_rate                                               -0.017066
# diabetes_prevalence                                                  0.074553
# female_smokers                                                      -0.074705
# male_smokers                                                        -0.165620
# handwashing_facilities                                               0.060996
# hospital_beds_per_thousand                                          -0.162644
# life_expectancy                                                     -0.132417
# human_development_index                                             -0.055650
# population                                                           0.918142
# excess_mortality_cumulative_absolute                                 1.000000
# excess_mortality_cumulative                                          0.258003
# excess_mortality                                                     0.139365
# excess_mortality_cumulative_per_million                              0.225009
# Life Expectancy (years) - Men                                       -0.137510
# Life Expectancy (years) - Women                                     -0.106920
# Happiness Score                                                     -0.025812
# Fertility Rate (births per woman)                                    0.086176
#
#                                          excess_mortality_cumulative  \
# total_cases                                                 0.019447
# total_deaths                                                0.180325
# total_cases_per_million                                    -0.056057
# total_deaths_per_million                                    0.451169
# reproduction_rate                                          -0.126011
# icu_patients                                                0.100055
# icu_patients_per_million                                    0.275500
# hosp_patients                                               0.118742
# hosp_patients_per_million                                   0.413500
# weekly_icu_admissions                                       0.094929
# weekly_icu_admissions_per_million                           0.347278
# weekly_hosp_admissions                                      0.391091
# weekly_hosp_admissions_per_million                          0.502739
# total_tests                                                -0.089684
# total_tests_per_thousand                                   -0.255958
# positive_rate                                               0.123107
# tests_per_case                                             -0.264519
# total_vaccinations                                          0.025699
# people_vaccinated                                           0.051139
# people_fully_vaccinated                                     0.034840
# total_boosters                                             -0.102992
# total_vaccinations_per_hundred                             -0.391667
# people_vaccinated_per_hundred                              -0.314707
# people_fully_vaccinated_per_hundred                        -0.337641
# total_boosters_per_hundred                                 -0.500013
# stringency_index                                           -0.152858
# population_density                                         -0.141791
# median_age                                                 -0.432775
# aged_65_older                                              -0.441635
# aged_70_older                                              -0.417795
# gdp_per_capita                                             -0.381390
# extreme_poverty                                             0.545035
# cardiovasc_death_rate                                       0.163741
# diabetes_prevalence                                         0.079776
# female_smokers                                             -0.282115
# male_smokers                                                0.139516
# handwashing_facilities                                     -0.146884
# hospital_beds_per_thousand                                 -0.298921
# life_expectancy                                            -0.422221
# human_development_index                                    -0.514867
# population                                                  0.081974
# excess_mortality_cumulative_absolute                        0.258003
# excess_mortality_cumulative                                 1.000000
# excess_mortality                                            0.758113
# excess_mortality_cumulative_per_million                     0.665606
# Life Expectancy (years) - Men                              -0.406494
# Life Expectancy (years) - Women                            -0.326160
# Happiness Score                                            -0.490941
# Fertility Rate (births per woman)                           0.352532
#
#                                          excess_mortality  \
# total_cases                                     -0.111634
# total_deaths                                     0.034547
# total_cases_per_million                         -0.200307
# total_deaths_per_million                         0.250236
# reproduction_rate                               -0.033201
# icu_patients                                    -0.079881
# icu_patients_per_million                         0.340472
# hosp_patients                                   -0.072691
# hosp_patients_per_million                        0.578668
# weekly_icu_admissions                           -0.494022
# weekly_icu_admissions_per_million                0.573606
# weekly_hosp_admissions                          -0.064738
# weekly_hosp_admissions_per_million               0.710358
# total_tests                                     -0.234662
# total_tests_per_thousand                        -0.299315
# positive_rate                                    0.236098
# tests_per_case                                  -0.263514
# total_vaccinations                              -0.109424
# people_vaccinated                               -0.082544
# people_fully_vaccinated                         -0.098275
# total_boosters                                  -0.228829
# total_vaccinations_per_hundred                  -0.337217
# people_vaccinated_per_hundred                   -0.281472
# people_fully_vaccinated_per_hundred             -0.299379
# total_boosters_per_hundred                      -0.535596
# stringency_index                                -0.080577
# population_density                              -0.133944
# median_age                                      -0.518615
# aged_65_older                                   -0.590558
# aged_70_older                                   -0.569652
# gdp_per_capita                                  -0.346302
# extreme_poverty                                  0.466298
# cardiovasc_death_rate                            0.179671
# diabetes_prevalence                              0.342809
# female_smokers                                  -0.380884
# male_smokers                                     0.176952
# handwashing_facilities                           0.046039
# hospital_beds_per_thousand                      -0.364693
# life_expectancy                                 -0.544481
# human_development_index                         -0.647824
# population                                      -0.044750
# excess_mortality_cumulative_absolute             0.139365
# excess_mortality_cumulative                      0.758113
# excess_mortality                                 1.000000
# excess_mortality_cumulative_per_million          0.489412
# Life Expectancy (years) - Men                   -0.499186
# Life Expectancy (years) - Women                 -0.483029
# Happiness Score                                 -0.539444
# Fertility Rate (births per woman)                0.402078
#
#                                          excess_mortality_cumulative_per_million  \
# total_cases                                                             0.058326
# total_deaths                                                            0.161195
# total_cases_per_million                                                 0.179994
# total_deaths_per_million                                                0.734644
# reproduction_rate                                                      -0.118787
# icu_patients                                                            0.081791
# icu_patients_per_million                                                0.424471
# hosp_patients                                                           0.136494
# hosp_patients_per_million                                               0.856739
# weekly_icu_admissions                                                  -0.026044
# weekly_icu_admissions_per_million                                       0.461375
# weekly_hosp_admissions                                                  0.279508
# weekly_hosp_admissions_per_million                                      0.698747
# total_tests                                                            -0.027935
# total_tests_per_thousand                                               -0.215017
# positive_rate                                                           0.079658
# tests_per_case                                                         -0.268275
# total_vaccinations                                                      0.020845
# people_vaccinated                                                       0.033005
# people_fully_vaccinated                                                 0.021336
# total_boosters                                                         -0.035665
# total_vaccinations_per_hundred                                         -0.504138
# people_vaccinated_per_hundred                                          -0.544762
# people_fully_vaccinated_per_hundred                                    -0.488662
# total_boosters_per_hundred                                             -0.384119
# stringency_index                                                       -0.195609
# population_density                                                     -0.181467
# median_age                                                              0.059302
# aged_65_older                                                           0.065262
# aged_70_older                                                           0.083371
# gdp_per_capita                                                         -0.469886
# extreme_poverty                                                         0.270794
# cardiovasc_death_rate                                                   0.509024
# diabetes_prevalence                                                    -0.185599
# female_smokers                                                          0.121404
# male_smokers                                                            0.456988
# handwashing_facilities                                                  0.107247
# hospital_beds_per_thousand                                              0.113448
# life_expectancy                                                        -0.416505
# human_development_index                                                -0.303433
# population                                                              0.058505
# excess_mortality_cumulative_absolute                                    0.225009
# excess_mortality_cumulative                                             0.665606
# excess_mortality                                                        0.489412
# excess_mortality_cumulative_per_million                                 1.000000
# Life Expectancy (years) - Men                                          -0.428935
# Life Expectancy (years) - Women                                        -0.314987
# Happiness Score                                                        -0.458155
# Fertility Rate (births per woman)                                      -0.072051
#
#                                          Life Expectancy (years) - Men  \
# total_cases                                                   0.117024
# total_deaths                                                  0.114845
# total_cases_per_million                                       0.602927
# total_deaths_per_million                                      0.411074
# reproduction_rate                                             0.180734
# icu_patients                                                 -0.089677
# icu_patients_per_million                                     -0.146569
# hosp_patients                                                -0.098621
# hosp_patients_per_million                                    -0.460204
# weekly_icu_admissions                                         0.179148
# weekly_icu_admissions_per_million                            -0.557905
# weekly_hosp_admissions                                       -0.301081
# weekly_hosp_admissions_per_million                           -0.792711
# total_tests                                                   0.111204
# total_tests_per_thousand                                      0.378646
# positive_rate                                                -0.333308
# tests_per_case                                                0.041995
# total_vaccinations                                            0.064198
# people_vaccinated                                             0.049334
# people_fully_vaccinated                                       0.063305
# total_boosters                                                0.074651
# total_vaccinations_per_hundred                                0.823424
# people_vaccinated_per_hundred                                 0.807621
# people_fully_vaccinated_per_hundred                           0.784287
# total_boosters_per_hundred                                    0.526651
# stringency_index                                              0.407782
# population_density                                            0.178141
# median_age                                                    0.840817
# aged_65_older                                                 0.717800
# aged_70_older                                                 0.704640
# gdp_per_capita                                                0.680093
# extreme_poverty                                              -0.717577
# cardiovasc_death_rate                                        -0.525266
# diabetes_prevalence                                           0.202543
# female_smokers                                                0.501077
# male_smokers                                                  0.055782
# handwashing_facilities                                        0.786688
# hospital_beds_per_thousand                                    0.474775
# life_expectancy                                               0.956652
# human_development_index                                       0.903670
# population                                                   -0.024765
# excess_mortality_cumulative_absolute                         -0.137510
# excess_mortality_cumulative                                  -0.406494
# excess_mortality                                             -0.499186
# excess_mortality_cumulative_per_million                      -0.428935
# Life Expectancy (years) - Men                                 1.000000
# Life Expectancy (years) - Women                               0.986396
# Happiness Score                                               0.891720
# Fertility Rate (births per woman)                            -0.838160
#
#                                          Life Expectancy (years) - Women  \
# total_cases                                                     0.104130
# total_deaths                                                    0.114086
# total_cases_per_million                                         0.601579
# total_deaths_per_million                                        0.451606
# reproduction_rate                                               0.164567
# icu_patients                                                   -0.046829
# icu_patients_per_million                                       -0.096261
# hosp_patients                                                  -0.038520
# hosp_patients_per_million                                      -0.437035
# weekly_icu_admissions                                           0.314733
# weekly_icu_admissions_per_million                              -0.474620
# weekly_hosp_admissions                                         -0.306510
# weekly_hosp_admissions_per_million                             -0.707395
# total_tests                                                     0.078163
# total_tests_per_thousand                                        0.346196
# positive_rate                                                  -0.294382
# tests_per_case                                                  0.055673
# total_vaccinations                                              0.058812
# people_vaccinated                                               0.039261
# people_fully_vaccinated                                         0.058409
# total_boosters                                                  0.103434
# total_vaccinations_per_hundred                                  0.805906
# people_vaccinated_per_hundred                                   0.798159
# people_fully_vaccinated_per_hundred                             0.773984
# total_boosters_per_hundred                                      0.472545
# stringency_index                                                0.408305
# population_density                                              0.156883
# median_age                                                      0.848051
# aged_65_older                                                   0.729287
# aged_70_older                                                   0.718826
# gdp_per_capita                                                  0.648683
# extreme_poverty                                                -0.734586
# cardiovasc_death_rate                                          -0.491386
# diabetes_prevalence                                             0.176960
# female_smokers                                                  0.499499
# male_smokers                                                    0.093269
# handwashing_facilities                                          0.776250
# hospital_beds_per_thousand                                      0.504008
# life_expectancy                                                 0.951419
# human_development_index                                         0.900672
# population                                                     -0.046640
# excess_mortality_cumulative_absolute                           -0.106920
# excess_mortality_cumulative                                    -0.326160
# excess_mortality                                               -0.483029
# excess_mortality_cumulative_per_million                        -0.314987
# Life Expectancy (years) - Men                                   0.986396
# Life Expectancy (years) - Women                                 1.000000
# Happiness Score                                                 0.877524
# Fertility Rate (births per woman)                              -0.851365
#
#                                          Happiness Score  \
# total_cases                                     0.136224
# total_deaths                                    0.142999
# total_cases_per_million                         0.573284
# total_deaths_per_million                        0.362388
# reproduction_rate                               0.101497
# icu_patients                                   -0.002483
# icu_patients_per_million                       -0.136788
# hosp_patients                                  -0.117752
# hosp_patients_per_million                      -0.584201
# weekly_icu_admissions                          -0.264514
# weekly_icu_admissions_per_million              -0.315840
# weekly_hosp_admissions                         -0.089223
# weekly_hosp_admissions_per_million             -0.638617
# total_tests                                     0.120612
# total_tests_per_thousand                        0.419608
# positive_rate                                  -0.384855
# tests_per_case                                  0.010651
# total_vaccinations                              0.026120
# people_vaccinated                               0.008221
# people_fully_vaccinated                         0.024411
# total_boosters                                  0.092095
# total_vaccinations_per_hundred                  0.803411
# people_vaccinated_per_hundred                   0.774627
# people_fully_vaccinated_per_hundred             0.764917
# total_boosters_per_hundred                      0.596850
# stringency_index                                0.326300
# population_density                              0.102428
# median_age                                      0.795493
# aged_65_older                                   0.704088
# aged_70_older                                   0.690970
# gdp_per_capita                                  0.720095
# extreme_poverty                                -0.660193
# cardiovasc_death_rate                          -0.567682
# diabetes_prevalence                             0.152540
# female_smokers                                  0.496336
# male_smokers                                   -0.104654
# handwashing_facilities                          0.740427
# hospital_beds_per_thousand                      0.462902
# life_expectancy                                 0.873968
# human_development_index                         0.902571
# population                                     -0.062944
# excess_mortality_cumulative_absolute           -0.025812
# excess_mortality_cumulative                    -0.490941
# excess_mortality                               -0.539444
# excess_mortality_cumulative_per_million        -0.458155
# Life Expectancy (years) - Men                   0.891720
# Life Expectancy (years) - Women                 0.877524
# Happiness Score                                 1.000000
# Fertility Rate (births per woman)              -0.746279
#
#                                          Fertility Rate (births per woman)
# total_cases                                                      -0.164034
# total_deaths                                                     -0.176556
# total_cases_per_million                                          -0.611932
# total_deaths_per_million                                         -0.523698
# reproduction_rate                                                -0.102062
# icu_patients                                                     -0.033729
# icu_patients_per_million                                         -0.236756
# hosp_patients                                                    -0.106504
# hosp_patients_per_million                                        -0.279441
# weekly_icu_admissions                                             0.006872
# weekly_icu_admissions_per_million                                -0.210153
# weekly_hosp_admissions                                            0.062899
# weekly_hosp_admissions_per_million                               -0.151375
# total_tests                                                      -0.138363
# total_tests_per_thousand                                         -0.300701
# positive_rate                                                     0.283373
# tests_per_case                                                   -0.077564
# total_vaccinations                                               -0.120401
# people_vaccinated                                                -0.114729
# people_fully_vaccinated                                          -0.119135
# total_boosters                                                   -0.166996
# total_vaccinations_per_hundred                                   -0.749397
# people_vaccinated_per_hundred                                    -0.777569
# people_fully_vaccinated_per_hundred                              -0.751105
# total_boosters_per_hundred                                       -0.328640
# stringency_index                                                 -0.522178
# population_density                                               -0.146626
# median_age                                                       -0.862167
# aged_65_older                                                    -0.674393
# aged_70_older                                                    -0.657202
# gdp_per_capita                                                   -0.507790
# extreme_poverty                                                   0.788506
# cardiovasc_death_rate                                             0.285004
# diabetes_prevalence                                              -0.263412
# female_smokers                                                   -0.466248
# male_smokers                                                     -0.318642
# handwashing_facilities                                           -0.792565
# hospital_beds_per_thousand                                       -0.527572
# life_expectancy                                                  -0.855400
# human_development_index                                          -0.866658
# population                                                       -0.052780
# excess_mortality_cumulative_absolute                              0.086176
# excess_mortality_cumulative                                       0.352532
# excess_mortality                                                  0.402078
# excess_mortality_cumulative_per_million                          -0.072051
# Life Expectancy (years) - Men                                    -0.838160
# Life Expectancy (years) - Women                                  -0.851365
# Happiness Score                                                  -0.746279
# Fertility Rate (births per woman)                                 1.000000
#
# [49 rows x 49 columns]
